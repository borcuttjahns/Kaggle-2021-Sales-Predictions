# %% [markdown]
# # Here Begins The Kaggle 2021 Experience

# %% [markdown]
# ### First, let's get some packages imported

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Now lets get our funcs

# %%
from MLfuncs.imports import getShops, getCategories, getItems, getSalesTrain, getSalesTest

# %%
shopsDF = getShops()
catDF = getCategories()
itemsDF = getItems()
salesTrain = getSalesTrain()
salesTest = getSalesTest()

# %% [markdown]
# ### Now lets see what we're working with

# %%
print(shopsDF.head(5))
print(catDF.head(5))
print(itemsDF.head(5))
print(salesTrain.head(5))
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# ### Whole bunch of Russian Stuff. Lets visualize some of this sales data.

# %%
sns.scatterplot(data=salesTrain, x="item_id", y="item_cnt_day")
# Out:
# <AxesSubplot:xlabel='item_id', ylabel='item_cnt_day'>

# %%
f, ax = plt.subplots()
sns.scatterplot(data=salesTrain, x="item_price", y="item_cnt_day", ax=ax)
ax.set(xscale="log", yscale="log")
# Out:
# [None, None]

# %%
shopsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   shop_name  60 non-null     object
#  1   shop_id    60 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
catDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   item_category_name  84 non-null     object
#  1   item_category_id    84 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.4+ KB

# %%
itemsDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22170 entries, 0 to 22169
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_name         22170 non-null  object
#  1   item_id           22170 non-null  int64
#  2   item_category_id  22170 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 519.7+ KB

# %%
salesTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
salesTrain = salesTrain.merge(shopsDF)
salesTrain = salesTrain.merge(itemsDF)
salesTrain = salesTrain.merge(catDF)
salesTrain
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154       999.0
# 1        02.01.2013               0       25    22154       999.0
# 2        03.01.2013               0       25    22154       999.0
# 3        20.01.2013               0       25    22154       999.0
# 4        23.01.2013               0       25    22154       999.0
# ...             ...             ...      ...      ...         ...
# 2935844  22.10.2015              33       55    13093       250.0
# 2935845  21.09.2015              32       55    13091      1000.0
# 2935846  16.09.2015              32       55    13094      2500.0
# 2935847  22.09.2015              32       55    13094      2500.0
# 2935848  26.10.2015              33       55    13092      2000.0
#
#          item_cnt_day                 shop_name  \
# 0                 1.0    Ярославль ТЦ "Альтаир"
# 1                 1.0       Москва ТРК "Атриум"
# 2                 1.0       Москва ТРК "Атриум"
# 3                 1.0       Москва ТРК "Атриум"
# 4                 1.0       Москва ТРК "Атриум"
# ...               ...                       ...
# 2935844           1.0  Цифровой склад 1С-Онлайн
# 2935845           1.0  Цифровой склад 1С-Онлайн
# 2935846           1.0  Цифровой склад 1С-Онлайн
# 2935847           2.0  Цифровой склад 1С-Онлайн
# 2935848           1.0  Цифровой склад 1С-Онлайн
#
#                                                  item_name  item_category_id  \
# 0                                        ЯВЛЕНИЕ 2012 (BD)                37
# 1                                        ЯВЛЕНИЕ 2012 (BD)                37
# 2                                        ЯВЛЕНИЕ 2012 (BD)                37
# 3                                        ЯВЛЕНИЕ 2012 (BD)                37
# 4                                        ЯВЛЕНИЕ 2012 (BD)                37
# ...                                                    ...               ...
# 2935844  Карта оплаты Windows: 250 рублей [Цифровая вер...                36
# 2935845  Карта оплаты Windows: 1000 рублей [Цифровая ве...                36
# 2935846  Карта оплаты Windows: 2500 рублей [Цифровая ве...                36
# 2935847  Карта оплаты Windows: 2500 рублей [Цифровая ве...                36
# 2935848  Карта оплаты Windows: 2000 рублей [Цифровая ве...                36
#
#                      item_category_name
# 0                        Кино - Blu-Ray
# 1                        Кино - Blu-Ray
# 2                        Кино - Blu-Ray
# 3                        Кино - Blu-Ray
# 4                        Кино - Blu-Ray
# ...                                 ...
# 2935844  Карты оплаты - Windows (Цифра)
# 2935845  Карты оплаты - Windows (Цифра)
# 2935846  Карты оплаты - Windows (Цифра)
# 2935847  Карты оплаты - Windows (Цифра)
# 2935848  Карты оплаты - Windows (Цифра)
#
# [2935849 rows x 10 columns]
